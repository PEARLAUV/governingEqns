# %% [markdown]
# # PEARL Governing Equations
#
# ## Overview
# * Power
# * Propulsion
# * Structure
# * Communication
# * Computing
# * Navigation
#
# ## Power
#
# ## Propulsion
# Propulsion - needs to overcome drag
#
# \begin{equation}
# E_p = \frac{\rho C_d S V^3}{2*\eta}\tau
# \end{equation}
#
# where
# * $E_p$ = energy required for propulsion to overcome drag [Ws]
# * $\rho$ = density of water [kg/m$^3$]
# * $C_d$ = drag coefficient
# * $S$ = wetted surface area of platform [m$^2$]
# * $V$ = velocity of platform [m/s]
# * $\eta$ = propulsion efficiency
# * $\tau$ = time of motion [s]
#
# ## Structure
#
# ## Communication
# Based off of link budget
#
# \begin{equation}
# \frac{E_b}{N_o} = \frac{P L_l G_t L_s L_a G_r}{k T_s R}
# \end{equation}
#
# where
# * $E_b$ = energy per bit [Ws]
# * $N_o$ =noise spectral density [W/Hz]
# * $P$ = transmitter power [W]
# * $L_l$ = transmitter to antenna line loss [dB]
# * $G_t$ = transmitter antenna line gain [dB]
# * $L_s$ = space loss [dB]
# * $L_a$ = transmission path loss [dB]
# * $G_r$ = receiver antenna gain [dB]
# * $k$ = Boltzmann's constant [J/K]
# * $T_s$ = system noise temperature [dBK]
# * $R$ = data rate [bits/sec = bps]
#
#
# Space loss due to transmission distance
#
# \begin{equation}
# L_s = \frac{\lambda}{4*\pi*S}^2
# \end{equation}
#
# where
# * $\lambda$ = transmitting wavelength
# * $S$ = distance [km]
#
# and
# \begin{equation}
# f = \lambda c
# \end{equation}
#
# where
# * $f$ = carrier frequency [Hz]
# * $c$ = speed of light in a vacuum [m/s]
#
# ## Computing
#
# ## Navigation
